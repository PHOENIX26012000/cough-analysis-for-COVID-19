# %%
import glob
a=glob.glob("/home/roy/Coswara-Data/*/*/*/cough*.wav")
print(a[0])
# Out:
# /home/roy/Coswara-Data/20200424/20200424/pOZwqBg4NsVYWASmwwhXFq4UlpC2/cough-heavy.wav

# %%
import re
import shutil
i=0;
for x in a:
    print(x)
    target = r'/home/roy/Coswara-Data/cough/cough'+str(i)+'.wav'
    shutil.copy(x,target)
    i+=1
# Out:
# /home/roy/Coswara-Data/20200424/20200424/pOZwqBg4NsVYWASmwwhXFq4UlpC2/cough-heavy.wav
# /home/roy/Coswara-Data/20200424/20200424/pOZwqBg4NsVYWASmwwhXFq4UlpC2/cough-shallow.wav
# /home/roy/Coswara-Data/20200424/20200424/GzhrTQhWHSTwvweRKx2x1Uh4wx52/cough-heavy.wav
# /home/roy/Coswara-Data/20200424/20200424/GzhrTQhWHSTwvweRKx2x1Uh4wx52/cough-shallow.wav
# /home/roy/Coswara-Data/20200424/20200424/C5eIsssb9GSkaAgIfsHMHeR6fSh1/cough-heavy.wav
# /home/roy/Coswara-Data/20200424/20200424/C5eIsssb9GSkaAgIfsHMHeR6fSh1/cough-shallow.wav
# /home/roy/Coswara-Data/20200424/20200424/nE9m0JsRXTYoni1nN9LpiBJJJXJ2/cough-heavy.wav
# /home/roy/Coswara-Data/20200424/20200424/nE9m0JsRXTYoni1nN9LpiBJJJXJ2/cough-shallow.wav
# /home/roy/Coswara-Data/20200424/20200424/2n0fnSeTNiWvPi7aLxRrFsCGU8D2/cough-heavy.wav
# /home/roy/Coswara-Data/20200424/20200424/2n0fnSeTNiWvPi7aLxRrFsCGU8D2/cough-shallow.wav
# /home/roy/Coswara-Data/20200424/20200424/vgaIxe6N8uQfcnstW4gWet53Amt2/cough-heavy.wav
# ...

# %%
print(i)
# Out:
# 2199
